# %% [markdown]
# Script to fix line duplication error for Matthew Lu's EEG data collection for 2021 Honours.
#
# Going to be analysing .vmrk files in the attached folder
#
#
# Algorithm to be implemented according to Matt's manual examination of the data:
#
# For subject 1 (similarity_01.vmrk)
# 1. Triggers "S 29", " S 30", "S 31" should not be in the data at all and should be deleted.
# 2. Fixation trigger S 10 should only be followed by the colour triggers S 1 to S 9 (e.g., S 10 → S 7). Anything else should be deleted.
# 3. Response screen trigger S 11 should only be followed by one rating trigger from (e.g., S 11 → S 15).
#    * Sometimes S 11 is followed by one extra rating trigger (e.g., S 11 → S 12 → S 15), sometimes two extra rating triggers (e.g., S 11 → S 12 → S 15 → S 19).
#    * In either case, it seems like the correct rating trigger is always the one that comes last. So S 15 and S 19 would be the correct triggers in the above example.
# 4. There are extra triggers for the colours (S 1 to S 9). These seem to always come before an actual colour trigger (e.g., S 6 → S 3). So if there are two consecutive colour triggers, the first one is the spurious one and should be deleted.
#
# And these are for subjects 2 to 8 (similarity_02.vmrk - similarity_08.vmrk).
#
# 1. First, if any of the lines contain a trigger that isn't S 1 to S 9 or S 11 to S 19, then they should be deleted (run this step first).
#
# And for all subjects
#
#  * If there are multiple consecutive lines that are within 10 samples of each other, then only the last line should be kept and the others deleted.
#    * E.g., S 6, 208776 → S 7, 208778. Delete S 6.
#    * E.g., S 18, 209900 → S 19, 209901 → S 15, 209902. Delete S 18 and S 19, keep S 15
#
# Written by Ariel Zeleznikow-Johnston on 2021-Aug-13
#
# ariel.zeleznikow-johnston@monash.edu

# %%
# libraries
import os
import re

# %%
# folder with data
folder = 'vmrk_raw/'

# %%
# list of acceptable stimuli
acceptable_subj_1 = [
             'S  1',
             'S  2',
             'S  3',
             'S  4',
             'S  5',
             'S  6',
             'S  7',
             'S  8',
             'S  9',
             'S 10',
             'S 11',
             'S 12',
             'S 13',
             'S 14',
             'S 15',
             'S 16',
             'S 17',
             'S 18',
             'S 19',]

acceptable_subj_2_9 = [
             'S  1',
             'S  2',
             'S  3',
             'S  4',
             'S  5',
             'S  6',
             'S  7',
             'S  8',
             'S  9',
             'S 11',
             'S 12',
             'S 13',
             'S 14',
             'S 15',
             'S 16',
             'S 17',
             'S 18',
             'S 19',]

after_s10 = ['S  1',
             'S  2',
             'S  3',
             'S  4',
             'S  5',
             'S  6',
             'S  7',
             'S  8',
             'S  9']

# %%
def load_vmrk(filename,diagnose=False):
  """Opening a file"""
  file = open(folder + filename,'r')
  lines = file.readlines()
  # testing
  if(diagnose):
    for i in range(100):
      print(lines[i])
  return lines

# %%
def get_files():
    """Get a list of all the vmrk files"""
    files = os.listdir(folder)
    return(files)

# %%
def write_corrected(filename):
    """Write a corrected file"""
    
    # get the data from the current file
    lines = load_vmrk(filename)
    
    # make a new folder
    if not os.path.exists('corrected_' + folder):
        os.makedirs('corrected_' + folder)
    # write a new file
    out_name = 'corrected_' + filename
    out_file = open('corrected_' + folder + out_name,'w')
    
    # write the header material
    write_header(lines,out_file)
    
    # write the data
    data = get_data(lines)
    
    if(filename == 'similarity_01.vmrk'): # subject 1 specific stuff
        data = initial_clean(data,acceptable_subj_1)
        data = subj_2_n_clean(data) # turns out Subject 1 needs this as well
        data = subj_1_clean(data)
        data = reindex(data)
    else: # everyone else
        data = initial_clean(data,acceptable_subj_2_9)
        data = subj_2_n_clean(data)
        data = reindex(data)
        
    for line in data:
        out_file.write(line)
    out_file.close()

# %%
def find_start(lines):
    """Find line on which the data starts"""
    count = 0
    for line in lines:
        count +=1
        if line.startswith('Mk3'):
            return count

# %%
def write_header(lines,out_file):
    """Write the header data across"""
    end_of_header = find_start(lines)
    i = 0
    while(i < end_of_header-1):
        out_file.write(lines[i])
        i += 1

# %%
def get_data(lines):
    return lines[(find_start(lines)-1):]

# %%
def get_stimulus(line):
    stim = re.search('lus,(.*?),',line)
    if stim:
        return stim.group(1)

# %%
def get_sample(line):
    return(int(line.split(',')[2]))

# %%
def initial_clean(data,acceptable):
    """Remove inappropriate triggers"""
    output_data = []
    for line in data:
        if get_stimulus(line) in acceptable:
            output_data.append(line)
    return output_data

# %%
def subj_1_clean(data):
    """Remove subject 1 specific issues"""
    output_data = []
    temp_data_s10 = []
    temp_data_response = []
    
    # Fixation trigger S 10 should only be followed by the colour triggers S 1 to S 9 (e.g., S 10 → S 7). Anything else should be deleted.
    # Remove two consecutive colour triggers
    i = 0
    length = len(data)
    while(i < length):
        if(get_stimulus(data[i]) == 'S 10'):
            temp_data_s10.append(data[i]) # add the S 10
            while (bool(get_stimulus(data[i + 1]) not in after_s10)): # skip until a colour found
                i += 1 # skip the inappropriate line
            if (bool(get_stimulus(data[i + 1]) in after_s10)): # if the next line also a colour, skip to it
                i += 1
            temp_data_s10.append(data[i])
            i +=1
        else:
            temp_data_s10.append(data[i])
            i += 1
    
    # Response screen trigger S 11 should only be followed by one rating trigger from (e.g., S 11 → S 15)
    i = 0
    while i < (len(temp_data_s10)):
        #print(i)
        #print(data[i])
        #print(get_stimulus(data[i]))
        if(get_stimulus(temp_data_s10[i]) == 'S 11'):
            temp_data_response.append(temp_data_s10[i])
            #print(i,'stim',get_stimulus(temp_data_s10[i]))
            while(get_stimulus(temp_data_s10[i]) != 'S 10'): # go looking for the colour trigger
                #print('bum')
                if(i == len(temp_data_s10)-1): # hit end of file
                    temp_data_response.append(temp_data_s10[i])
                    return temp_data_response
                i += 1
            temp_data_response.append(temp_data_s10[i - 1]) # add only the last correct response
            temp_data_response.append(temp_data_s10[i]) # add the S 10 we're on now
            i += 1
        else:
            temp_data_response.append(temp_data_s10[i])
            i += 1
    
    # should be good now
    for line in temp_data_response:
        print(line)

# %%
def subj_2_n_clean(data):
    """Remove subject 2...n specific issues"""
    # If there are multiple consecutive lines that are within 10 samples of each other, then only the last line should be kept and the others deleted.
    out_data = []
    i = 0
    while i < (len(data)):
        if (get_sample(data[i + 1]) - get_sample(data[i]) > 10):
            out_data.append(data[i])
        i += 1
        if i == (len(data) - 1):
            out_data.append(data[i])
            return(out_data)

# %%
def reindex(data):
    """Reindex the lines"""
    out_data =[]
    i = 3 # data starts on Mk3
    for line in data:
        temp = line.split('=')
        index = 'Mk' + str(i) + '='
        out_data.append(index+temp[1])
        i +=1
    return(out_data)

# %% [markdown]
# Main call

# %%
# run the script
files = get_files()
for file in files:
    write_corrected(file)

# %% [markdown]
# ### Playing/testing to get it to work

# %%
write_corrected('similarity_01.vmrk')

# %%
test_lines = load_vmrk('similarity_02.vmrk')
find_start(test_lines)
test_line = test_lines[15]
print(test_line)
print(get_stimulus(test_line))
print(get_sample(test_line))
# Out:
# Mk5=Stimulus,S 11,23458,1,0
#
# S 11
# 23458

# %%
test_data = get_data(test_lines)
print(len(test_data))
print()
print(len(initial_clean(test_data,acceptable_subj_1)))
subj_1_test = initial_clean(test_data,acceptable_subj_1)
# Out:
# 5889
#
# 5584

# %%
find_start(test_lines)
print(test_data[0])
print(subj_1_test[0])
# Out:
# Mk3=Stimulus,S  5,22650,1,0
#
# Mk3=Stimulus,S  5,22650,1,0

# %%
len(subj_1_test)
# Out:
# 5584

# %%
reindex(subj_2_n_clean(subj_1_test))
# Out:
# ['Mk3=Stimulus,S  5,22650,1,0\n',
#  'Mk4=Stimulus,S  7,23308,1,0\n',
#  'Mk5=Stimulus,S 11,23458,1,0\n',
#  'Mk6=Stimulus,S 14,24633,1,0\n',
#  'Mk7=Stimulus,S  2,26967,1,0\n',
#  'Mk8=Stimulus,S 11,27117,1,0\n',
#  'Mk9=Stimulus,S 18,28108,1,0\n',
#  'Mk10=Stimulus,S  4,29317,1,0\n',
#  'Mk11=Stimulus,S 11,29467,1,0\n',
#  'Mk12=Stimulus,S 18,30484,1,0\n',
#  'Mk13=Stimulus,S  7,31750,1,0\n',
#  'Mk14=Stimulus,S 11,31900,1,0\n',
#  'Mk15=Stimulus,S 15,32867,1,0\n',
#  'Mk16=Stimulus,S  7,34067,1,0\n',
#  'Mk17=Stimulus,S 11,34217,1,0\n',
#  'Mk18=Stimulus,S 12,34942,1,0\n',
#  'Mk19=Stimulus,S  3,37309,1,0\n',
#  'Mk20=Stimulus,S 11,37459,1,0\n',
#  'Mk21=Stimulus,S 17,38217,1,0\n',
#  'Mk22=Stimulus,S  1,39425,1,0\n',
#  'Mk23=Stimulus,S 11,39575,1,0\n',
#  'Mk24=Stimulus,S 18,40509,1,0\n',
#  'Mk25=Stimulus,S  2,41634,1,0\n',
#  'Mk26=Stimulus,S 11,41784,1,0\n',
#  'Mk27=Stimulus,S 14,42350,1,0\n',
#  'Mk28=Stimulus,S  6,44834,1,0\n',
#  'Mk29=Stimulus,S 11,44984,1,0\n',
#  'Mk30=Stimulus,S 19,45767,1,0\n',
#  'Mk31=Stimulus,S  8,46834,1,0\n',
#  'Mk32=Stimulus,S 11,46984,1,0\n',
#  'Mk33=Stimulus,S 15,48500,1,0\n',
#  'Mk34=Stimulus,S  6,49834,1,0\n',
#  'Mk35=Stimulus,S 11,49984,1,0\n',
#  'Mk36=Stimulus,S 16,50884,1,0\n',
#  'Mk37=Stimulus,S  3,52192,1,0\n',
#  'Mk38=Stimulus,S 11,52342,1,0\n',
#  'Mk39=Stimulus,S 17,53000,1,0\n',
#  'Mk40=Stimulus,S  5,54209,1,0\n',
#  'Mk41=Stimulus,S 11,54359,1,0\n',
#  'Mk42=Stimulus,S 14,55434,1,0\n',
#  'Mk43=Stimulus,S  2,56567,1,0\n',
#  'Mk44=Stimulus,S 11,56717,1,0\n',
#  'Mk45=Stimulus,S 17,57550,1,0\n',
#  'Mk46=Stimulus,S  8,58742,1,0\n',
#  'Mk47=Stimulus,S 11,58892,1,0\n',
#  'Mk48=Stimulus,S 18,59759,1,0\n',
#  'Mk49=Stimulus,S  9,60776,1,0\n',
#  'Mk50=Stimulus,S 11,60926,1,0\n',
#  'Mk51=Stimulus,S 15,61926,1,0\n',
#  'Mk52=Stimulus,S  6,62859,1,0\n',
#  'Mk53=Stimulus,S 11,63009,1,0\n',
#  'Mk54=Stimulus,S 19,63692,1,0\n',
#  'Mk55=Stimulus,S  7,64551,1,0\n',
#  'Mk56=Stimulus,S 11,64701,1,0\n',
#  'Mk57=Stimulus,S 14,65484,1,0\n',
#  'Mk58=Stimulus,S  6,66434,1,0\n',
#  'Mk59=Stimulus,S 11,66584,1,0\n',
#  'Mk60=Stimulus,S 13,67159,1,0\n',
#  'Mk61=Stimulus,S  4,68417,1,0\n',
#  'Mk62=Stimulus,S 11,68567,1,0\n',
#  'Mk63=Stimulus,S 16,69459,1,0\n',
#  'Mk64=Stimulus,S  3,70642,1,0\n',
#  'Mk65=Stimulus,S 11,70792,1,0\n',
#  'Mk66=Stimulus,S 13,71251,1,0\n',
#  'Mk67=Stimulus,S  8,72292,1,0\n',
#  'Mk68=Stimulus,S 11,72442,1,0\n',
#  'Mk69=Stimulus,S 19,73126,1,0\n',
#  'Mk70=Stimulus,S  1,74442,1,0\n',
#  'Mk71=Stimulus,S 11,74592,1,0\n',
#  'Mk72=Stimulus,S 16,76117,1,0\n',
#  'Mk73=Stimulus,S  8,77284,1,0\n',
#  'Mk74=Stimulus,S 11,77434,1,0\n',
#  'Mk75=Stimulus,S 19,77934,1,0\n',
#  'Mk76=Stimulus,S  7,78909,1,0\n',
#  'Mk77=Stimulus,S 11,79067,1,0\n',
#  'Mk78=Stimulus,S 16,80151,1,0\n',
#  'Mk79=Stimulus,S  5,81092,1,0\n',
#  'Mk80=Stimulus,S 11,81242,1,0\n',
#  'Mk81=Stimulus,S 14,81951,1,0\n',
#  'Mk82=Stimulus,S  1,83117,1,0\n',
#  'Mk83=Stimulus,S 11,83267,1,0\n',
#  'Mk84=Stimulus,S 19,83992,1,0\n',
#  'Mk85=Stimulus,S  9,84917,1,0\n',
#  'Mk86=Stimulus,S 11,85067,1,0\n',
#  'Mk87=Stimulus,S 14,86009,1,0\n',
#  'Mk88=Stimulus,S  9,86992,1,0\n',
#  'Mk89=Stimulus,S 11,87142,1,0\n',
#  'Mk90=Stimulus,S 12,87593,1,0\n',
#  'Mk91=Stimulus,S  7,88534,1,0\n',
#  'Mk92=Stimulus,S 11,88684,1,0\n',
#  'Mk93=Stimulus,S 19,89284,1,0\n',
#  'Mk94=Stimulus,S  7,90209,1,0\n',
#  'Mk95=Stimulus,S 11,90359,1,0\n',
#  'Mk96=Stimulus,S 12,90784,1,0\n',
#  'Mk97=Stimulus,S  9,91651,1,0\n',
#  'Mk98=Stimulus,S 11,91801,1,0\n',
#  'Mk99=Stimulus,S 19,92318,1,0\n',
#  'Mk100=Stimulus,S  2,93201,1,0\n',
#  'Mk101=Stimulus,S 11,93351,1,0\n',
#  'Mk102=Stimulus,S 16,93876,1,0\n',
#  'Mk103=Stimulus,S  6,94726,1,0\n',
#  'Mk104=Stimulus,S 11,94876,1,0\n',
#  'Mk105=Stimulus,S 18,95959,1,0\n',
#  'Mk106=Stimulus,S  7,96784,1,0\n',
#  'Mk107=Stimulus,S 11,96934,1,0\n',
#  'Mk108=Stimulus,S 14,97459,1,0\n',
#  'Mk109=Stimulus,S  8,98418,1,0\n',
#  'Mk110=Stimulus,S 11,98568,1,0\n',
#  'Mk111=Stimulus,S 16,99984,1,0\n',
#  'Mk112=Stimulus,S  5,100918,1,0\n',
#  'Mk113=Stimulus,S 11,101068,1,0\n',
#  'Mk114=Stimulus,S 19,101668,1,0\n',
#  'Mk115=Stimulus,S  5,102584,1,0\n',
#  'Mk116=Stimulus,S 11,102734,1,0\n',
#  'Mk117=Stimulus,S 12,103184,1,0\n',
#  'Mk118=Stimulus,S  3,104084,1,0\n',
#  'Mk119=Stimulus,S 11,104234,1,0\n',
#  'Mk120=Stimulus,S 14,104684,1,0\n',
#  'Mk121=Stimulus,S  2,105559,1,0\n',
#  'Mk122=Stimulus,S 11,105709,1,0\n',
#  'Mk123=Stimulus,S 17,106101,1,0\n',
#  'Mk124=Stimulus,S  5,107076,1,0\n',
#  'Mk125=Stimulus,S 11,107226,1,0\n',
#  'Mk126=Stimulus,S 18,108109,1,0\n',
#  'Mk127=Stimulus,S  1,108976,1,0\n',
#  'Mk128=Stimulus,S 11,109126,1,0\n',
#  'Mk129=Stimulus,S 19,109609,1,0\n',
#  'Mk130=Stimulus,S  4,110484,1,0\n',
#  'Mk131=Stimulus,S 11,110634,1,0\n',
#  'Mk132=Stimulus,S 19,111168,1,0\n',
#  'Mk133=Stimulus,S  4,112009,1,0\n',
#  'Mk134=Stimulus,S 11,112159,1,0\n',
#  'Mk135=Stimulus,S 12,112551,1,0\n',
#  'Mk136=Stimulus,S  3,113493,1,0\n',
#  'Mk137=Stimulus,S 11,113643,1,0\n',
#  'Mk138=Stimulus,S 14,114126,1,0\n',
#  'Mk139=Stimulus,S  5,115001,1,0\n',
#  'Mk140=Stimulus,S 11,115151,1,0\n',
#  'Mk141=Stimulus,S 14,115576,1,0\n',
#  'Mk142=Stimulus,S  3,116476,1,0\n',
#  'Mk143=Stimulus,S 11,116626,1,0\n',
#  'Mk144=Stimulus,S 14,117068,1,0\n',
#  'Mk145=Stimulus,S  9,117876,1,0\n',
#  'Mk146=Stimulus,S 11,118026,1,0\n',
#  'Mk147=Stimulus,S 19,118343,1,0\n',
#  'Mk148=Stimulus,S  8,119193,1,0\n',
#  'Mk149=Stimulus,S 11,119343,1,0\n',
#  'Mk150=Stimulus,S 15,120426,1,0\n',
#  'Mk151=Stimulus,S  8,121401,1,0\n',
#  'Mk152=Stimulus,S 11,121551,1,0\n',
#  'Mk153=Stimulus,S 12,121985,1,0\n',
#  'Mk154=Stimulus,S  4,122851,1,0\n',
#  'Mk155=Stimulus,S 11,123001,1,0\n',
#  'Mk156=Stimulus,S 19,123818,1,0\n',
#  'Mk157=Stimulus,S  3,124685,1,0\n',
#  'Mk158=Stimulus,S 11,124835,1,0\n',
#  'Mk159=Stimulus,S 14,125343,1,0\n',
#  'Mk160=Stimulus,S  9,126218,1,0\n',
#  'Mk161=Stimulus,S 11,126368,1,0\n',
#  'Mk162=Stimulus,S 19,126760,1,0\n',
#  'Mk163=Stimulus,S  3,127576,1,0\n',
#  'Mk164=Stimulus,S 11,127726,1,0\n',
#  'Mk165=Stimulus,S 19,128226,1,0\n',
#  'Mk166=Stimulus,S  2,129026,1,0\n',
#  'Mk167=Stimulus,S 11,129176,1,0\n',
#  'Mk168=Stimulus,S 16,130726,1,0\n',
#  'Mk169=Stimulus,S  5,131568,1,0\n',
#  'Mk170=Stimulus,S 11,131718,1,0\n',
#  'Mk171=Stimulus,S 18,132760,1,0\n',
#  'Mk172=Stimulus,S  5,133601,1,0\n',
#  'Mk173=Stimulus,S 11,133751,1,0\n',
#  'Mk174=Stimulus,S 12,134493,1,0\n',
#  'Mk175=Stimulus,S  8,135385,1,0\n',
#  'Mk176=Stimulus,S 11,135535,1,0\n',
#  'Mk177=Stimulus,S 16,136601,1,0\n',
#  'Mk178=Stimulus,S  8,137485,1,0\n',
#  'Mk179=Stimulus,S 11,137635,1,0\n',
#  'Mk180=Stimulus,S 12,137901,1,0\n',
#  'Mk181=Stimulus,S  5,138801,1,0\n',
#  'Mk182=Stimulus,S 11,138951,1,0\n',
#  'Mk183=Stimulus,S 18,140451,1,0\n',
#  'Mk184=Stimulus,S  9,141276,1,0\n',
#  'Mk185=Stimulus,S 11,141426,1,0\n',
#  'Mk186=Stimulus,S 19,142135,1,0\n',
#  'Mk187=Stimulus,S  9,142943,1,0\n',
#  'Mk188=Stimulus,S 11,143093,1,0\n',
#  'Mk189=Stimulus,S 15,144535,1,0\n',
#  'Mk190=Stimulus,S  2,145401,1,0\n',
#  'Mk191=Stimulus,S 11,145551,1,0\n',
#  'Mk192=Stimulus,S 17,146327,1,0\n',
#  'Mk193=Stimulus,S  7,147201,1,0\n',
#  'Mk194=Stimulus,S 11,147351,1,0\n',
#  'Mk195=Stimulus,S 18,149077,1,0\n',
#  'Mk196=Stimulus,S  3,149885,1,0\n',
#  'Mk197=Stimulus,S 11,150035,1,0\n',
#  'Mk198=Stimulus,S 15,150677,1,0\n',
#  'Mk199=Stimulus,S  7,151510,1,0\n',
#  'Mk200=Stimulus,S 11,151660,1,0\n',
#  'Mk201=Stimulus,S 15,152052,1,0\n',
#  'Mk202=Stimulus,S  7,152893,1,0\n',
#  'Mk203=Stimulus,S 11,153043,1,0\n',
#  'Mk204=Stimulus,S 12,153360,1,0\n',
#  'Mk205=Stimulus,S  6,154202,1,0\n',
#  'Mk206=Stimulus,S 11,154352,1,0\n',
#  'Mk207=Stimulus,S 13,154760,1,0\n',
#  'Mk208=Stimulus,S  9,155577,1,0\n',
#  'Mk209=Stimulus,S 11,155727,1,0\n',
#  'Mk210=Stimulus,S 19,156085,1,0\n',
#  'Mk211=Stimulus,S  8,156877,1,0\n',
#  'Mk212=Stimulus,S 11,157027,1,0\n',
#  'Mk213=Stimulus,S 15,157810,1,0\n',
#  'Mk214=Stimulus,S  9,158785,1,0\n',
#  'Mk215=Stimulus,S 11,158935,1,0\n',
#  'Mk216=Stimulus,S 15,159277,1,0\n',
#  'Mk217=Stimulus,S  4,160143,1,0\n',
#  'Mk218=Stimulus,S 11,160293,1,0\n',
#  'Mk219=Stimulus,S 19,160785,1,0\n',
#  'Mk220=Stimulus,S  3,161660,1,0\n',
#  'Mk221=Stimulus,S 11,161810,1,0\n',
#  'Mk222=Stimulus,S 14,162485,1,0\n',
#  'Mk223=Stimulus,S  6,165110,1,0\n',
#  'Mk224=Stimulus,S 11,165260,1,0\n',
#  'Mk225=Stimulus,S 13,165777,1,0\n',
#  'Mk226=Stimulus,S  2,169143,1,0\n',
#  'Mk227=Stimulus,S 11,169293,1,0\n',
#  'Mk228=Stimulus,S 19,169752,1,0\n',
#  'Mk229=Stimulus,S  8,170577,1,0\n',
#  'Mk230=Stimulus,S 11,170727,1,0\n',
#  'Mk231=Stimulus,S 16,171452,1,0\n',
#  'Mk232=Stimulus,S  5,172260,1,0\n',
#  'Mk233=Stimulus,S 11,172410,1,0\n',
#  'Mk234=Stimulus,S 19,173127,1,0\n',
#  'Mk235=Stimulus,S  9,173918,1,0\n',
#  'Mk236=Stimulus,S 11,174068,1,0\n',
#  'Mk237=Stimulus,S 19,174469,1,0\n',
#  'Mk238=Stimulus,S  8,175893,1,0\n',
#  'Mk239=Stimulus,S 11,176043,1,0\n',
#  'Mk240=Stimulus,S 15,176794,1,0\n',
#  'Mk241=Stimulus,S  7,177818,1,0\n',
#  'Mk242=Stimulus,S 11,177968,1,0\n',
#  'Mk243=Stimulus,S 16,178902,1,0\n',
#  'Mk244=Stimulus,S  5,179802,1,0\n',
#  'Mk245=Stimulus,S 11,179952,1,0\n',
#  'Mk246=Stimulus,S 15,180635,1,0\n',
#  'Mk247=Stimulus,S  3,181644,1,0\n',
#  'Mk248=Stimulus,S 11,181794,1,0\n',
#  'Mk249=Stimulus,S 14,182394,1,0\n',
#  'Mk250=Stimulus,S  2,183294,1,0\n',
#  'Mk251=Stimulus,S 11,183444,1,0\n',
#  'Mk252=Stimulus,S 15,184719,1,0\n',
#  'Mk253=Stimulus,S  1,185852,1,0\n',
#  'Mk254=Stimulus,S 11,186002,1,0\n',
#  'Mk255=Stimulus,S 14,187619,1,0\n',
#  'Mk256=Stimulus,S  9,188469,1,0\n',
#  'Mk257=Stimulus,S 11,188619,1,0\n',
#  'Mk258=Stimulus,S 14,189144,1,0\n',
#  'Mk259=Stimulus,S  1,189952,1,0\n',
#  'Mk260=Stimulus,S 11,190102,1,0\n',
#  'Mk261=Stimulus,S 14,190377,1,0\n',
#  'Mk262=Stimulus,S  7,191202,1,0\n',
#  'Mk263=Stimulus,S 11,191352,1,0\n',
#  'Mk264=Stimulus,S 19,191719,1,0\n',
#  'Mk265=Stimulus,S  7,192527,1,0\n',
#  'Mk266=Stimulus,S 11,192677,1,0\n',
#  'Mk267=Stimulus,S 12,193210,1,0\n',
#  'Mk268=Stimulus,S  4,194077,1,0\n',
#  'Mk269=Stimulus,S 11,194227,1,0\n',
#  'Mk270=Stimulus,S 15,195594,1,0\n',
#  'Mk271=Stimulus,S  2,196427,1,0\n',
#  'Mk272=Stimulus,S 11,196577,1,0\n',
#  'Mk273=Stimulus,S 16,197419,1,0\n',
#  'Mk274=Stimulus,S  1,198244,1,0\n',
#  'Mk275=Stimulus,S 11,198394,1,0\n',
#  'Mk276=Stimulus,S 15,199019,1,0\n',
#  'Mk277=Stimulus,S  1,199860,1,0\n',
#  'Mk278=Stimulus,S 11,200010,1,0\n',
#  'Mk279=Stimulus,S 15,201302,1,0\n',
#  'Mk280=Stimulus,S  1,203319,1,0\n',
#  'Mk281=Stimulus,S 11,203469,1,0\n',
#  'Mk282=Stimulus,S 12,203786,1,0\n',
#  'Mk283=Stimulus,S  6,204744,1,0\n',
#  'Mk284=Stimulus,S 11,204894,1,0\n',
#  'Mk285=Stimulus,S 19,205336,1,0\n',
#  'Mk286=Stimulus,S  2,206160,1,0\n',
#  'Mk287=Stimulus,S 11,206310,1,0\n',
#  'Mk288=Stimulus,S 18,206811,1,0\n',
#  'Mk289=Stimulus,S  9,207619,1,0\n',
#  'Mk290=Stimulus,S 11,207769,1,0\n',
#  'Mk291=Stimulus,S 16,208452,1,0\n',
#  'Mk292=Stimulus,S  6,209261,1,0\n',
#  'Mk293=Stimulus,S 11,209410,1,0\n',
#  'Mk294=Stimulus,S 18,210511,1,0\n',
#  'Mk295=Stimulus,S  6,211311,1,0\n',
#  'Mk296=Stimulus,S 11,211461,1,0\n',
#  'Mk297=Stimulus,S 12,212144,1,0\n',
#  'Mk298=Stimulus,S  6,212986,1,0\n',
#  'Mk299=Stimulus,S 11,213136,1,0\n',
#  'Mk300=Stimulus,S 12,213502,1,0\n',
#  'Mk301=Stimulus,S  2,214802,1,0\n',
#  'Mk302=Stimulus,S 11,214952,1,0\n',
#  'Mk303=Stimulus,S 18,216269,1,0\n',
#  'Mk304=Stimulus,S  1,217102,1,0\n',
#  'Mk305=Stimulus,S 11,217252,1,0\n',
#  'Mk306=Stimulus,S 15,217936,1,0\n',
#  'Mk307=Stimulus,S  7,219069,1,0\n',
#  'Mk308=Stimulus,S 11,219219,1,0\n',
#  'Mk309=Stimulus,S 18,220069,1,0\n',
#  'Mk310=Stimulus,S  3,221411,1,0\n',
#  'Mk311=Stimulus,S 11,221561,1,0\n',
#  'Mk312=Stimulus,S 16,222286,1,0\n',
#  'Mk313=Stimulus,S  1,223194,1,0\n',
#  'Mk314=Stimulus,S 11,223344,1,0\n',
#  'Mk315=Stimulus,S 19,224286,1,0\n',
#  'Mk316=Stimulus,S  8,226594,1,0\n',
#  'Mk317=Stimulus,S 11,226744,1,0\n',
#  'Mk318=Stimulus,S 16,227269,1,0\n',
#  'Mk319=Stimulus,S  1,228294,1,0\n',
#  'Mk320=Stimulus,S 11,228444,1,0\n',
#  'Mk321=Stimulus,S 17,229344,1,0\n',
#  'Mk322=Stimulus,S  5,230319,1,0\n',
#  'Mk323=Stimulus,S 11,230469,1,0\n',
#  'Mk324=Stimulus,S 19,231661,1,0\n',
#  'Mk325=Stimulus,S  4,232519,1,0\n',
#  'Mk326=Stimulus,S 11,232669,1,0\n',
#  'Mk327=Stimulus,S 15,234028,1,0\n',
#  'Mk328=Stimulus,S  8,234927,1,0\n',
#  'Mk329=Stimulus,S 11,235077,1,0\n',
#  'Mk330=Stimulus,S 17,236803,1,0\n',
#  'Mk331=Stimulus,S  2,237736,1,0\n',
#  'Mk332=Stimulus,S 11,237886,1,0\n',
#  'Mk333=Stimulus,S 18,239178,1,0\n',
#  'Mk334=Stimulus,S  1,240119,1,0\n',
#  'Mk335=Stimulus,S 11,240269,1,0\n',
#  'Mk336=Stimulus,S 16,241669,1,0\n',
#  'Mk337=Stimulus,S  5,242719,1,0\n',
#  'Mk338=Stimulus,S 11,242869,1,0\n',
#  'Mk339=Stimulus,S 19,243686,1,0\n',
#  'Mk340=Stimulus,S  6,244486,1,0\n',
#  'Mk341=Stimulus,S 11,244636,1,0\n',
#  'Mk342=Stimulus,S 15,245969,1,0\n',
#  'Mk343=Stimulus,S  1,247011,1,0\n',
#  'Mk344=Stimulus,S 11,247161,1,0\n',
#  'Mk345=Stimulus,S 19,247703,1,0\n',
#  'Mk346=Stimulus,S  5,248486,1,0\n',
#  'Mk347=Stimulus,S 11,248636,1,0\n',
#  'Mk348=Stimulus,S 19,249028,1,0\n',
#  'Mk349=Stimulus,S  6,249778,1,0\n',
#  'Mk350=Stimulus,S 11,249928,1,0\n',
#  'Mk351=Stimulus,S 15,251094,1,0\n',
#  'Mk352=Stimulus,S  4,251886,1,0\n',
#  'Mk353=Stimulus,S 11,252036,1,0\n',
#  'Mk354=Stimulus,S 16,253169,1,0\n',
#  'Mk355=Stimulus,S  8,254003,1,0\n',
#  'Mk356=Stimulus,S 11,254153,1,0\n',
#  'Mk357=Stimulus,S 19,255244,1,0\n',
#  'Mk358=Stimulus,S  9,256111,1,0\n',
#  'Mk359=Stimulus,S 11,256261,1,0\n',
#  'Mk360=Stimulus,S 15,256678,1,0\n',
#  'Mk361=Stimulus,S  6,257469,1,0\n',
#  'Mk362=Stimulus,S 11,257619,1,0\n',
#  'Mk363=Stimulus,S 18,258436,1,0\n',
#  'Mk364=Stimulus,S  4,259178,1,0\n',
#  'Mk365=Stimulus,S 11,259328,1,0\n',
#  'Mk366=Stimulus,S 16,259861,1,0\n',
#  'Mk367=Stimulus,S  9,260619,1,0\n',
#  'Mk368=Stimulus,S 11,260769,1,0\n',
#  'Mk369=Stimulus,S 19,261719,1,0\n',
#  'Mk370=Stimulus,S  1,262436,1,0\n',
#  'Mk371=Stimulus,S 11,262586,1,0\n',
#  'Mk372=Stimulus,S 16,263511,1,0\n',
#  'Mk373=Stimulus,S  3,264261,1,0\n',
#  'Mk374=Stimulus,S 11,264411,1,0\n',
#  'Mk375=Stimulus,S 19,265486,1,0\n',
#  'Mk376=Stimulus,S  6,266211,1,0\n',
#  'Mk377=Stimulus,S 11,266361,1,0\n',
#  'Mk378=Stimulus,S 16,266761,1,0\n',
#  'Mk379=Stimulus,S  5,267511,1,0\n',
#  'Mk380=Stimulus,S 11,267661,1,0\n',
#  'Mk381=Stimulus,S 15,268386,1,0\n',
#  'Mk382=Stimulus,S  3,269211,1,0\n',
#  'Mk383=Stimulus,S 11,269361,1,0\n',
#  'Mk384=Stimulus,S 15,269753,1,0\n',
#  'Mk385=Stimulus,S  4,270495,1,0\n',
#  'Mk386=Stimulus,S 11,270644,1,0\n',
#  'Mk387=Stimulus,S 13,271153,1,0\n',
#  'Mk388=Stimulus,S  8,271961,1,0\n',
#  'Mk389=Stimulus,S 11,272111,1,0\n',
#  'Mk390=Stimulus,S 19,272511,1,0\n',
#  'Mk391=Stimulus,S  4,273278,1,0\n',
#  'Mk392=Stimulus,S 11,273428,1,0\n',
#  'Mk393=Stimulus,S 17,274936,1,0\n',
#  'Mk394=Stimulus,S  7,275828,1,0\n',
#  'Mk395=Stimulus,S 11,275978,1,0\n',
#  'Mk396=Stimulus,S 17,276420,1,0\n',
#  'Mk397=Stimulus,S  4,277311,1,0\n',
#  'Mk398=Stimulus,S 11,277461,1,0\n',
#  'Mk399=Stimulus,S 17,279911,1,0\n',
#  'Mk400=Stimulus,S  4,280736,1,0\n',
#  'Mk401=Stimulus,S 11,280886,1,0\n',
#  'Mk402=Stimulus,S 13,281411,1,0\n',
#  'Mk403=Stimulus,S  6,282220,1,0\n',
#  'Mk404=Stimulus,S 11,282370,1,0\n',
#  'Mk405=Stimulus,S 16,282836,1,0\n',
#  'Mk406=Stimulus,S  5,283703,1,0\n',
#  'Mk407=Stimulus,S 11,283853,1,0\n',
#  'Mk408=Stimulus,S 14,284311,1,0\n',
#  'Mk409=Stimulus,S  7,285103,1,0\n',
#  'Mk410=Stimulus,S 11,285253,1,0\n',
#  'Mk411=Stimulus,S 16,286445,1,0\n',
#  'Mk412=Stimulus,S  7,287428,1,0\n',
#  'Mk413=Stimulus,S 11,287578,1,0\n',
#  'Mk414=Stimulus,S 12,288020,1,0\n',
#  'Mk415=Stimulus,S  1,288811,1,0\n',
#  'Mk416=Stimulus,S 11,288961,1,0\n',
#  'Mk417=Stimulus,S 19,289320,1,0\n',
#  'Mk418=Stimulus,S  8,290045,1,0\n',
#  'Mk419=Stimulus,S 11,290195,1,0\n',
#  'Mk420=Stimulus,S 18,291503,1,0\n',
#  'Mk421=Stimulus,S  3,292228,1,0\n',
#  'Mk422=Stimulus,S 11,292378,1,0\n',
#  'Mk423=Stimulus,S 19,294012,1,0\n',
#  'Mk424=Stimulus,S  2,294795,1,0\n',
#  'Mk425=Stimulus,S 11,294945,1,0\n',
#  'Mk426=Stimulus,S 16,296103,1,0\n',
#  'Mk427=Stimulus,S  2,296861,1,0\n',
#  'Mk428=Stimulus,S 11,297011,1,0\n',
#  'Mk429=Stimulus,S 12,297437,1,0\n',
#  'Mk430=Stimulus,S  3,298186,1,0\n',
#  'Mk431=Stimulus,S 11,298336,1,0\n',
#  'Mk432=Stimulus,S 17,299762,1,0\n',
#  'Mk433=Stimulus,S  3,300512,1,0\n',
#  'Mk434=Stimulus,S 11,300661,1,0\n',
#  'Mk435=Stimulus,S 12,301053,1,0\n',
#  'Mk436=Stimulus,S  2,301787,1,0\n',
#  'Mk437=Stimulus,S 11,301937,1,0\n',
#  'Mk438=Stimulus,S 16,302837,1,0\n',
#  'Mk439=Stimulus,S  4,303595,1,0\n',
#  'Mk440=Stimulus,S 11,303745,1,0\n',
#  'Mk441=Stimulus,S 16,304745,1,0\n',
#  'Mk442=Stimulus,S  9,305770,1,0\n',
#  'Mk443=Stimulus,S 11,305920,1,0\n',
#  'Mk444=Stimulus,S 19,306370,1,0\n',
#  'Mk445=Stimulus,S  5,310137,1,0\n',
#  'Mk446=Stimulus,S 11,310287,1,0\n',
#  'Mk447=Stimulus,S 19,311020,1,0\n',
#  'Mk448=Stimulus,S  2,311887,1,0\n',
#  'Mk449=Stimulus,S 11,312037,1,0\n',
#  'Mk450=Stimulus,S 18,312878,1,0\n',
#  'Mk451=Stimulus,S  3,314253,1,0\n',
#  'Mk452=Stimulus,S 11,314403,1,0\n',
#  'Mk453=Stimulus,S 15,314870,1,0\n',
#  'Mk454=Stimulus,S  4,315803,1,0\n',
#  'Mk455=Stimulus,S 11,315953,1,0\n',
#  'Mk456=Stimulus,S 13,316820,1,0\n',
#  'Mk457=Stimulus,S  5,317620,1,0\n',
#  'Mk458=Stimulus,S 11,317770,1,0\n',
#  'Mk459=Stimulus,S 14,318120,1,0\n',
#  'Mk460=Stimulus,S  1,318987,1,0\n',
#  'Mk461=Stimulus,S 11,319137,1,0\n',
#  'Mk462=Stimulus,S 19,319578,1,0\n',
#  'Mk463=Stimulus,S  4,320328,1,0\n',
#  'Mk464=Stimulus,S 11,320478,1,0\n',
#  'Mk465=Stimulus,S 17,321670,1,0\n',
#  'Mk466=Stimulus,S  4,322562,1,0\n',
#  'Mk467=Stimulus,S 11,322712,1,0\n',
#  'Mk468=Stimulus,S 12,323045,1,0\n',
#  'Mk469=Stimulus,S  1,323895,1,0\n',
#  'Mk470=Stimulus,S 11,324045,1,0\n',
#  'Mk471=Stimulus,S 19,324404,1,0\n',
#  'Mk472=Stimulus,S  8,325437,1,0\n',
#  'Mk473=Stimulus,S 11,325587,1,0\n',
#  'Mk474=Stimulus,S 18,326070,1,0\n',
#  'Mk475=Stimulus,S  6,326853,1,0\n',
#  'Mk476=Stimulus,S 11,327003,1,0\n',
#  'Mk477=Stimulus,S 17,327512,1,0\n',
#  'Mk478=Stimulus,S  9,328320,1,0\n',
#  'Mk479=Stimulus,S 11,328470,1,0\n',
#  'Mk480=Stimulus,S 19,328920,1,0\n',
#  'Mk481=Stimulus,S  2,329778,1,0\n',
#  'Mk482=Stimulus,S 11,329937,1,0\n',
#  'Mk483=Stimulus,S 17,330795,1,0\n',
#  'Mk484=Stimulus,S  6,331562,1,0\n',
#  'Mk485=Stimulus,S 11,331712,1,0\n',
#  'Mk486=Stimulus,S 18,332829,1,0\n',
#  'Mk487=Stimulus,S  9,333620,1,0\n',
#  'Mk488=Stimulus,S 11,333770,1,0\n',
#  'Mk489=Stimulus,S 19,334304,1,0\n',
#  'Mk490=Stimulus,S  5,379362,1,0\n',
#  'Mk491=Stimulus,S  7,380021,1,0\n',
#  'Mk492=Stimulus,S 11,380171,1,0\n',
#  'Mk493=Stimulus,S 15,380746,1,0\n',
#  'Mk494=Stimulus,S  2,381612,1,0\n',
#  'Mk495=Stimulus,S 11,381762,1,0\n',
#  'Mk496=Stimulus,S 19,382187,1,0\n',
#  'Mk497=Stimulus,S  4,382979,1,0\n',
#  'Mk498=Stimulus,S 11,383129,1,0\n',
#  'Mk499=Stimulus,S 18,383504,1,0\n',
#  'Mk500=Stimulus,S  7,384279,1,0\n',
#  'Mk501=Stimulus,S 11,384429,1,0\n',
#  'Mk502=Stimulus,S 16,385346,1,0\n',
#  'Mk503=Stimulus,S  7,386171,1,0\n',
#  'Mk504=Stimulus,S 11,386321,1,0\n',
#  'Mk505=Stimulus,S 12,386696,1,0\n',
#  'Mk506=Stimulus,S  3,387521,1,0\n',
#  'Mk507=Stimulus,S 11,387671,1,0\n',
#  'Mk508=Stimulus,S 16,388204,1,0\n',
#  'Mk509=Stimulus,S  1,388971,1,0\n',
#  'Mk510=Stimulus,S 11,389121,1,0\n',
#  'Mk511=Stimulus,S 19,389529,1,0\n',
#  'Mk512=Stimulus,S  2,390271,1,0\n',
#  'Mk513=Stimulus,S 11,390421,1,0\n',
#  'Mk514=Stimulus,S 15,391096,1,0\n',
#  'Mk515=Stimulus,S  6,391912,1,0\n',
#  'Mk516=Stimulus,S 11,392062,1,0\n',
#  'Mk517=Stimulus,S 19,392397,1,0\n',
#  'Mk518=Stimulus,S  8,393162,1,0\n',
#  'Mk519=Stimulus,S 11,393312,1,0\n',
#  'Mk520=Stimulus,S 16,394138,1,0\n',
#  'Mk521=Stimulus,S  6,395037,1,0\n',
#  'Mk522=Stimulus,S 11,395187,1,0\n',
#  'Mk523=Stimulus,S 17,396146,1,0\n',
#  'Mk524=Stimulus,S  3,397162,1,0\n',
#  'Mk525=Stimulus,S 11,397313,1,0\n',
#  'Mk526=Stimulus,S 17,397763,1,0\n',
#  'Mk527=Stimulus,S  5,398637,1,0\n',
#  'Mk528=Stimulus,S 11,398788,1,0\n',
#  'Mk529=Stimulus,S 15,399563,1,0\n',
#  'Mk530=Stimulus,S  2,400337,1,0\n',
#  'Mk531=Stimulus,S 11,400488,1,0\n',
#  'Mk532=Stimulus,S 18,401104,1,0\n',
#  'Mk533=Stimulus,S  8,401854,1,0\n',
#  'Mk534=Stimulus,S 11,402004,1,0\n',
#  'Mk535=Stimulus,S 18,403338,1,0\n',
#  'Mk536=Stimulus,S  9,404238,1,0\n',
#  'Mk537=Stimulus,S 11,404388,1,0\n',
#  'Mk538=Stimulus,S 16,404854,1,0\n',
#  'Mk539=Stimulus,S  6,405754,1,0\n',
#  'Mk540=Stimulus,S 11,405904,1,0\n',
#  'Mk541=Stimulus,S 18,406513,1,0\n',
#  'Mk542=Stimulus,S  7,407288,1,0\n',
#  'Mk543=Stimulus,S 11,407438,1,0\n',
#  'Mk544=Stimulus,S 14,408030,1,0\n',
#  'Mk545=Stimulus,S  6,408888,1,0\n',
#  'Mk546=Stimulus,S 11,409038,1,0\n',
#  'Mk547=Stimulus,S 13,409496,1,0\n',
#  'Mk548=Stimulus,S  4,410279,1,0\n',
#  'Mk549=Stimulus,S 11,410429,1,0\n',
#  'Mk550=Stimulus,S 17,411071,1,0\n',
#  'Mk551=Stimulus,S  3,411846,1,0\n',
#  'Mk552=Stimulus,S 11,411996,1,0\n',
#  'Mk553=Stimulus,S 15,412446,1,0\n',
#  'Mk554=Stimulus,S  8,413196,1,0\n',
#  'Mk555=Stimulus,S 11,413346,1,0\n',
#  'Mk556=Stimulus,S 18,413846,1,0\n',
#  'Mk557=Stimulus,S  1,414596,1,0\n',
#  'Mk558=Stimulus,S 11,414746,1,0\n',
#  'Mk559=Stimulus,S 18,415188,1,0\n',
#  'Mk560=Stimulus,S  8,415938,1,0\n',
#  'Mk561=Stimulus,S 11,416088,1,0\n',
#  'Mk562=Stimulus,S 17,416821,1,0\n',
#  'Mk563=Stimulus,S  7,417546,1,0\n',
#  'Mk564=Stimulus,S 11,417696,1,0\n',
#  'Mk565=Stimulus,S 17,418071,1,0\n',
#  'Mk566=Stimulus,S  5,418838,1,0\n',
#  'Mk567=Stimulus,S 11,418988,1,0\n',
#  'Mk568=Stimulus,S 17,419546,1,0\n',
#  'Mk569=Stimulus,S  1,420246,1,0\n',
#  'Mk570=Stimulus,S 11,420396,1,0\n',
#  'Mk571=Stimulus,S 19,420930,1,0\n',
#  'Mk572=Stimulus,S  9,421638,1,0\n',
#  'Mk573=Stimulus,S 11,421788,1,0\n',
#  'Mk574=Stimulus,S 16,422256,1,0\n',
#  'Mk575=Stimulus,S  9,422979,1,0\n',
#  'Mk576=Stimulus,S 11,423129,1,0\n',
#  'Mk577=Stimulus,S 12,423796,1,0\n',
#  'Mk578=Stimulus,S  7,424479,1,0\n',
#  'Mk579=Stimulus,S 11,424629,1,0\n',
#  'Mk580=Stimulus,S 19,424996,1,0\n',
#  'Mk581=Stimulus,S  7,425688,1,0\n',
#  'Mk582=Stimulus,S 11,425838,1,0\n',
#  'Mk583=Stimulus,S 12,426113,1,0\n',
#  'Mk584=Stimulus,S  9,426804,1,0\n',
#  'Mk585=Stimulus,S 11,426954,1,0\n',
#  'Mk586=Stimulus,S 19,427246,1,0\n',
#  'Mk587=Stimulus,S  2,427938,1,0\n',
#  'Mk588=Stimulus,S 11,428088,1,0\n',
#  'Mk589=Stimulus,S 17,428580,1,0\n',
#  'Mk590=Stimulus,S  6,429296,1,0\n',
#  'Mk591=Stimulus,S 11,429446,1,0\n',
#  'Mk592=Stimulus,S 19,429763,1,0\n',
#  'Mk593=Stimulus,S  7,430446,1,0\n',
#  'Mk594=Stimulus,S 11,430596,1,0\n',
#  'Mk595=Stimulus,S 14,430930,1,0\n',
#  'Mk596=Stimulus,S  8,431630,1,0\n',
#  'Mk597=Stimulus,S 11,431780,1,0\n',
#  'Mk598=Stimulus,S 14,432371,1,0\n',
#  'Mk599=Stimulus,S  5,433063,1,0\n',
#  'Mk600=Stimulus,S 11,433213,1,0\n',
#  'Mk601=Stimulus,S 19,433621,1,0\n',
#  'Mk602=Stimulus,S  5,434288,1,0\n',
#  'Mk603=Stimulus,S 11,434438,1,0\n',
#  'Mk604=Stimulus,S 12,434821,1,0\n',
#  'Mk605=Stimulus,S  3,435505,1,0\n',
#  'Mk606=Stimulus,S 11,435655,1,0\n',
#  'Mk607=Stimulus,S 15,436163,1,0\n',
#  'Mk608=Stimulus,S  2,437546,1,0\n',
#  'Mk609=Stimulus,S 11,437696,1,0\n',
#  'Mk610=Stimulus,S 17,438005,1,0\n',
#  'Mk611=Stimulus,S  5,438738,1,0\n',
#  'Mk612=Stimulus,S 11,438888,1,0\n',
#  'Mk613=Stimulus,S 18,440546,1,0\n',
#  'Mk614=Stimulus,S  1,441346,1,0\n',
#  'Mk615=Stimulus,S 11,441496,1,0\n',
#  'Mk616=Stimulus,S 19,441871,1,0\n',
#  'Mk617=Stimulus,S  4,442546,1,0\n',
#  'Mk618=Stimulus,S 11,442696,1,0\n',
#  'Mk619=Stimulus,S 19,443122,1,0\n',
#  'Mk620=Stimulus,S  4,443788,1,0\n',
#  'Mk621=Stimulus,S 11,443938,1,0\n',
#  'Mk622=Stimulus,S 12,444213,1,0\n',
#  'Mk623=Stimulus,S  3,444905,1,0\n',
#  'Mk624=Stimulus,S 11,445055,1,0\n',
#  'Mk625=Stimulus,S 14,445588,1,0\n',
#  'Mk626=Stimulus,S  5,446280,1,0\n',
#  'Mk627=Stimulus,S 11,446430,1,0\n',
#  'Mk628=Stimulus,S 15,446922,1,0\n',
#  'Mk629=Stimulus,S  3,447605,1,0\n',
#  'Mk630=Stimulus,S 11,447755,1,0\n',
#  'Mk631=Stimulus,S 15,448105,1,0\n',
#  'Mk632=Stimulus,S  9,448796,1,0\n',
#  'Mk633=Stimulus,S 11,448946,1,0\n',
#  'Mk634=Stimulus,S 19,449322,1,0\n',
#  'Mk635=Stimulus,S  8,449988,1,0\n',
#  'Mk636=Stimulus,S 11,450138,1,0\n',
#  'Mk637=Stimulus,S 16,450588,1,0\n',
#  'Mk638=Stimulus,S  8,451296,1,0\n',
#  'Mk639=Stimulus,S 11,451446,1,0\n',
#  'Mk640=Stimulus,S 12,451747,1,0\n',
#  'Mk641=Stimulus,S  4,452405,1,0\n',
#  'Mk642=Stimulus,S 11,452555,1,0\n',
#  'Mk643=Stimulus,S 19,453038,1,0\n',
#  'Mk644=Stimulus,S  3,453696,1,0\n',
#  'Mk645=Stimulus,S 11,453846,1,0\n',
#  'Mk646=Stimulus,S 15,454263,1,0\n',
#  'Mk647=Stimulus,S  9,455030,1,0\n',
#  'Mk648=Stimulus,S 11,455180,1,0\n',
#  'Mk649=Stimulus,S 19,455805,1,0\n',
#  'Mk650=Stimulus,S  3,456438,1,0\n',
#  'Mk651=Stimulus,S 11,456588,1,0\n',
#  'Mk652=Stimulus,S 19,457563,1,0\n',
#  'Mk653=Stimulus,S  2,458246,1,0\n',
#  'Mk654=Stimulus,S 11,458396,1,0\n',
#  'Mk655=Stimulus,S 17,458997,1,0\n',
#  'Mk656=Stimulus,S  5,459680,1,0\n',
#  'Mk657=Stimulus,S 11,459830,1,0\n',
#  'Mk658=Stimulus,S 18,462705,1,0\n',
#  'Mk659=Stimulus,S  5,463430,1,0\n',
#  'Mk660=Stimulus,S 11,463580,1,0\n',
#  'Mk661=Stimulus,S 12,464014,1,0\n',
#  'Mk662=Stimulus,S  8,464713,1,0\n',
#  'Mk663=Stimulus,S 11,464863,1,0\n',
#  'Mk664=Stimulus,S 16,465539,1,0\n',
#  'Mk665=Stimulus,S  8,466272,1,0\n',
#  'Mk666=Stimulus,S 11,466422,1,0\n',
#  'Mk667=Stimulus,S 12,466897,1,0\n',
#  'Mk668=Stimulus,S  5,467605,1,0\n',
#  'Mk669=Stimulus,S 11,467755,1,0\n',
#  'Mk670=Stimulus,S 17,468681,1,0\n',
#  'Mk671=Stimulus,S  9,469388,1,0\n',
#  'Mk672=Stimulus,S 11,469538,1,0\n',
#  'Mk673=Stimulus,S 18,470172,1,0\n',
#  'Mk674=Stimulus,S  9,470847,1,0\n',
#  'Mk675=Stimulus,S 11,470997,1,0\n',
#  'Mk676=Stimulus,S 12,471322,1,0\n',
#  'Mk677=Stimulus,S  2,471997,1,0\n',
#  'Mk678=Stimulus,S 11,472147,1,0\n',
#  'Mk679=Stimulus,S 16,473147,1,0\n',
#  'Mk680=Stimulus,S  7,473988,1,0\n',
#  'Mk681=Stimulus,S 11,474138,1,0\n',
#  'Mk682=Stimulus,S 19,474788,1,0\n',
#  'Mk683=Stimulus,S  3,475472,1,0\n',
#  'Mk684=Stimulus,S 11,475622,1,0\n',
#  'Mk685=Stimulus,S 17,476655,1,0\n',
#  'Mk686=Stimulus,S  7,477363,1,0\n',
#  'Mk687=Stimulus,S 11,477513,1,0\n',
#  'Mk688=Stimulus,S 17,477938,1,0\n',
#  'Mk689=Stimulus,S  7,478697,1,0\n',
#  'Mk690=Stimulus,S 11,478847,1,0\n',
#  'Mk691=Stimulus,S 12,479255,1,0\n',
#  'Mk692=Stimulus,S  6,479930,1,0\n',
#  'Mk693=Stimulus,S 11,480080,1,0\n',
#  'Mk694=Stimulus,S 13,480455,1,0\n',
#  'Mk695=Stimulus,S  9,481155,1,0\n',
#  'Mk696=Stimulus,S 11,481305,1,0\n',
#  'Mk697=Stimulus,S 19,481789,1,0\n',
#  'Mk698=Stimulus,S  8,482447,1,0\n',
#  'Mk699=Stimulus,S 11,482597,1,0\n',
#  'Mk700=Stimulus,S 15,483122,1,0\n',
#  'Mk701=Stimulus,S  9,483822,1,0\n',
#  'Mk702=Stimulus,S 11,483972,1,0\n',
#  'Mk703=Stimulus,S 15,484589,1,0\n',
#  'Mk704=Stimulus,S  4,485280,1,0\n',
#  'Mk705=Stimulus,S 11,485430,1,0\n',
#  'Mk706=Stimulus,S 19,485797,1,0\n',
#  'Mk707=Stimulus,S  3,486455,1,0\n',
#  'Mk708=Stimulus,S 11,486605,1,0\n',
#  'Mk709=Stimulus,S 16,487031,1,0\n',
#  'Mk710=Stimulus,S  6,487705,1,0\n',
#  'Mk711=Stimulus,S 11,487855,1,0\n',
#  'Mk712=Stimulus,S 19,488797,1,0\n',
#  'Mk713=Stimulus,S  2,489463,1,0\n',
#  'Mk714=Stimulus,S 11,489613,1,0\n',
#  'Mk715=Stimulus,S 17,490314,1,0\n',
#  'Mk716=Stimulus,S  8,491030,1,0\n',
#  'Mk717=Stimulus,S 11,491180,1,0\n',
#  'Mk718=Stimulus,S 18,492189,1,0\n',
#  'Mk719=Stimulus,S  5,492864,1,0\n',
#  'Mk720=Stimulus,S 11,493014,1,0\n',
#  'Mk721=Stimulus,S 18,494122,1,0\n',
#  'Mk722=Stimulus,S  9,494805,1,0\n',
#  'Mk723=Stimulus,S 11,494955,1,0\n',
#  'Mk724=Stimulus,S 18,496230,1,0\n',
#  'Mk725=Stimulus,S  8,496897,1,0\n',
#  'Mk726=Stimulus,S 11,497047,1,0\n',
#  'Mk727=Stimulus,S 16,497472,1,0\n',
#  'Mk728=Stimulus,S  7,498172,1,0\n',
#  'Mk729=Stimulus,S 11,498322,1,0\n',
#  'Mk730=Stimulus,S 15,499172,1,0\n',
#  'Mk731=Stimulus,S  5,499864,1,0\n',
#  'Mk732=Stimulus,S 11,500014,1,0\n',
#  'Mk733=Stimulus,S 16,500414,1,0\n',
#  'Mk734=Stimulus,S  3,501089,1,0\n',
#  'Mk735=Stimulus,S 11,501239,1,0\n',
#  'Mk736=Stimulus,S 16,502247,1,0\n',
#  'Mk737=Stimulus,S  2,502939,1,0\n',
#  'Mk738=Stimulus,S 11,503089,1,0\n',
#  'Mk739=Stimulus,S 17,504165,1,0\n',
#  'Mk740=Stimulus,S  1,504864,1,0\n',
#  'Mk741=Stimulus,S 11,505014,1,0\n',
#  'Mk742=Stimulus,S 17,506206,1,0\n',
#  'Mk743=Stimulus,S  9,506922,1,0\n',
#  'Mk744=Stimulus,S 11,507072,1,0\n',
#  'Mk745=Stimulus,S 16,507456,1,0\n',
#  'Mk746=Stimulus,S  1,508164,1,0\n',
#  'Mk747=Stimulus,S 11,508314,1,0\n',
#  'Mk748=Stimulus,S 16,508789,1,0\n',
#  'Mk749=Stimulus,S  7,509464,1,0\n',
#  'Mk750=Stimulus,S 11,509614,1,0\n',
#  'Mk751=Stimulus,S 19,509989,1,0\n',
#  'Mk752=Stimulus,S  7,510639,1,0\n',
#  'Mk753=Stimulus,S 11,510789,1,0\n',
#  'Mk754=Stimulus,S 17,512982,1,0\n',
#  'Mk755=Stimulus,S  4,513655,1,0\n',
#  'Mk756=Stimulus,S 11,513805,1,0\n',
#  'Mk757=Stimulus,S 17,515506,1,0\n',
#  'Mk758=Stimulus,S  2,516205,1,0\n',
#  'Mk759=Stimulus,S 11,516355,1,0\n',
#  'Mk760=Stimulus,S 18,517581,1,0\n',
#  'Mk761=Stimulus,S  1,518247,1,0\n',
#  'Mk762=Stimulus,S 11,518397,1,0\n',
#  'Mk763=Stimulus,S 16,519097,1,0\n',
#  'Mk764=Stimulus,S  1,519947,1,0\n',
#  'Mk765=Stimulus,S 11,520097,1,0\n',
#  'Mk766=Stimulus,S 12,520582,1,0\n',
#  'Mk767=Stimulus,S  1,521264,1,0\n',
#  'Mk768=Stimulus,S 11,521414,1,0\n',
#  'Mk769=Stimulus,S 12,522172,1,0\n',
#  'Mk770=Stimulus,S  6,522822,1,0\n',
#  'Mk771=Stimulus,S 11,522972,1,0\n',
#  'Mk772=Stimulus,S 19,524214,1,0\n',
#  'Mk773=Stimulus,S  2,524889,1,0\n',
#  'Mk774=Stimulus,S 11,525039,1,0\n',
#  'Mk775=Stimulus,S 17,526464,1,0\n',
#  'Mk776=Stimulus,S  9,527147,1,0\n',
#  'Mk777=Stimulus,S 11,527297,1,0\n',
#  'Mk778=Stimulus,S 17,527831,1,0\n',
#  'Mk779=Stimulus,S  6,528672,1,0\n',
#  'Mk780=Stimulus,S 11,528822,1,0\n',
#  'Mk781=Stimulus,S 19,529114,1,0\n',
#  'Mk782=Stimulus,S  6,529756,1,0\n',
#  'Mk783=Stimulus,S 11,529906,1,0\n',
#  'Mk784=Stimulus,S 12,530322,1,0\n',
#  'Mk785=Stimulus,S  6,530956,1,0\n',
#  'Mk786=Stimulus,S 11,531106,1,0\n',
#  'Mk787=Stimulus,S 12,531589,1,0\n',
#  'Mk788=Stimulus,S  2,532222,1,0\n',
#  'Mk789=Stimulus,S 11,532372,1,0\n',
#  'Mk790=Stimulus,S 18,533081,1,0\n',
#  'Mk791=Stimulus,S  1,533764,1,0\n',
#  'Mk792=Stimulus,S 11,533914,1,0\n',
#  'Mk793=Stimulus,S 16,534698,1,0\n',
#  'Mk794=Stimulus,S  7,535372,1,0\n',
#  'Mk795=Stimulus,S 11,535522,1,0\n',
#  'Mk796=Stimulus,S 19,535914,1,0\n',
#  'Mk797=Stimulus,S  3,536564,1,0\n',
#  'Mk798=Stimulus,S 11,536714,1,0\n',
#  'Mk799=Stimulus,S 18,538189,1,0\n',
#  'Mk800=Stimulus,S  1,538856,1,0\n',
#  'Mk801=Stimulus,S 11,539006,1,0\n',
#  'Mk802=Stimulus,S 18,539581,1,0\n',
#  'Mk803=Stimulus,S  8,540256,1,0\n',
#  'Mk804=Stimulus,S 11,540406,1,0\n',
#  'Mk805=Stimulus,S 16,540839,1,0\n',
#  'Mk806=Stimulus,S  1,541506,1,0\n',
#  'Mk807=Stimulus,S 11,541656,1,0\n',
#  'Mk808=Stimulus,S 16,542389,1,0\n',
#  'Mk809=Stimulus,S  5,543056,1,0\n',
#  'Mk810=Stimulus,S 11,543206,1,0\n',
#  'Mk811=Stimulus,S 19,543673,1,0\n',
#  'Mk812=Stimulus,S  4,544339,1,0\n',
#  'Mk813=Stimulus,S 11,544489,1,0\n',
#  'Mk814=Stimulus,S 16,545156,1,0\n',
#  'Mk815=Stimulus,S  8,545822,1,0\n',
#  'Mk816=Stimulus,S 11,545972,1,0\n',
#  'Mk817=Stimulus,S 19,547181,1,0\n',
#  'Mk818=Stimulus,S  2,547872,1,0\n',
#  'Mk819=Stimulus,S 11,548022,1,0\n',
#  'Mk820=Stimulus,S 18,548931,1,0\n',
#  'Mk821=Stimulus,S  1,549606,1,0\n',
#  'Mk822=Stimulus,S 11,549756,1,0\n',
#  'Mk823=Stimulus,S 16,550356,1,0\n',
#  'Mk824=Stimulus,S  5,551206,1,0\n',
#  'Mk825=Stimulus,S 11,551356,1,0\n',
#  'Mk826=Stimulus,S 19,551914,1,0\n',
#  'Mk827=Stimulus,S  6,552547,1,0\n',
#  'Mk828=Stimulus,S 11,552697,1,0\n',
#  'Mk829=Stimulus,S 15,553324,1,0\n',
#  'Mk830=Stimulus,S  1,554022,1,0\n',
#  'Mk831=Stimulus,S 11,554172,1,0\n',
#  'Mk832=Stimulus,S 19,554681,1,0\n',
#  'Mk833=Stimulus,S  5,555331,1,0\n',
#  'Mk834=Stimulus,S 11,555481,1,0\n',
#  'Mk835=Stimulus,S 19,555806,1,0\n',
#  'Mk836=Stimulus,S  6,556431,1,0\n',
#  'Mk837=Stimulus,S 11,556581,1,0\n',
#  'Mk838=Stimulus,S 19,557073,1,0\n',
#  'Mk839=Stimulus,S  4,557714,1,0\n',
#  'Mk840=Stimulus,S 11,557864,1,0\n',
#  'Mk841=Stimulus,S 17,558931,1,0\n',
#  'Mk842=Stimulus,S  8,559614,1,0\n',
#  'Mk843=Stimulus,S 11,559764,1,0\n',
#  'Mk844=Stimulus,S 18,560839,1,0\n',
#  'Mk845=Stimulus,S  9,561506,1,0\n',
#  'Mk846=Stimulus,S 11,561656,1,0\n',
#  'Mk847=Stimulus,S 17,563398,1,0\n',
#  'Mk848=Stimulus,S  6,564056,1,0\n',
#  'Mk849=Stimulus,S 11,564206,1,0\n',
#  'Mk850=Stimulus,S 19,565090,1,0\n',
#  'Mk851=Stimulus,S  4,565748,1,0\n',
#  'Mk852=Stimulus,S 11,565898,1,0\n',
#  'Mk853=Stimulus,S 17,566640,1,0\n',
#  'Mk854=Stimulus,S  9,567348,1,0\n',
#  'Mk855=Stimulus,S 11,567498,1,0\n',
#  'Mk856=Stimulus,S 19,568090,1,0\n',
#  'Mk857=Stimulus,S  1,568773,1,0\n',
#  'Mk858=Stimulus,S 11,568923,1,0\n',
#  'Mk859=Stimulus,S 16,569998,1,0\n',
#  'Mk860=Stimulus,S  3,570739,1,0\n',
#  'Mk861=Stimulus,S 11,570889,1,0\n',
#  'Mk862=Stimulus,S 19,571523,1,0\n',
#  'Mk863=Stimulus,S  6,572206,1,0\n',
#  'Mk864=Stimulus,S 11,572356,1,0\n',
#  'Mk865=Stimulus,S 18,572998,1,0\n',
#  'Mk866=Stimulus,S  5,574364,1,0\n',
#  'Mk867=Stimulus,S 11,574514,1,0\n',
#  'Mk868=Stimulus,S 15,576590,1,0\n',
#  'Mk869=Stimulus,S  3,577406,1,0\n',
#  'Mk870=Stimulus,S 11,577556,1,0\n',
#  'Mk871=Stimulus,S 15,579248,1,0\n',
#  'Mk872=Stimulus,S  4,580064,1,0\n',
#  'Mk873=Stimulus,S 11,580214,1,0\n',
#  'Mk874=Stimulus,S 14,580598,1,0\n',
#  'Mk875=Stimulus,S  8,581323,1,0\n',
#  'Mk876=Stimulus,S 11,581473,1,0\n',
#  'Mk877=Stimulus,S 19,582206,1,0\n',
#  'Mk878=Stimulus,S  4,582864,1,0\n',
#  'Mk879=Stimulus,S 11,583014,1,0\n',
#  'Mk880=Stimulus,S 19,583548,1,0\n',
#  'Mk881=Stimulus,S  7,584606,1,0\n',
#  'Mk882=Stimulus,S 11,584756,1,0\n',
#  'Mk883=Stimulus,S 18,585640,1,0\n',
#  'Mk884=Stimulus,S  4,586781,1,0\n',
#  'Mk885=Stimulus,S 11,586931,1,0\n',
#  'Mk886=Stimulus,S 17,587448,1,0\n',
#  'Mk887=Stimulus,S  4,588131,1,0\n',
#  'Mk888=Stimulus,S 11,588281,1,0\n',
#  'Mk889=Stimulus,S 12,588631,1,0\n',
#  'Mk890=Stimulus,S  6,589298,1,0\n',
#  'Mk891=Stimulus,S 11,589448,1,0\n',
#  'Mk892=Stimulus,S 16,590281,1,0\n',
#  'Mk893=Stimulus,S  5,591306,1,0\n',
#  'Mk894=Stimulus,S 11,591456,1,0\n',
#  'Mk895=Stimulus,S 15,591973,1,0\n',
#  'Mk896=Stimulus,S  7,592715,1,0\n',
#  'Mk897=Stimulus,S 11,592865,1,0\n',
#  'Mk898=Stimulus,S 16,594590,1,0\n',
#  'Mk899=Stimulus,S  7,595398,1,0\n',
#  'Mk900=Stimulus,S 11,595548,1,0\n',
#  'Mk901=Stimulus,S 12,595990,1,0\n',
#  'Mk902=Stimulus,S  1,596956,1,0\n',
#  'Mk903=Stimulus,S 11,597106,1,0\n',
#  'Mk904=Stimulus,S 19,598082,1,0\n',
#  'Mk905=Stimulus,S  8,598806,1,0\n',
#  'Mk906=Stimulus,S 11,598956,1,0\n',
#  'Mk907=Stimulus,S 18,600699,1,0\n',
#  'Mk908=Stimulus,S  3,601465,1,0\n',
#  'Mk909=Stimulus,S 11,601615,1,0\n',
#  'Mk910=Stimulus,S 18,603107,1,0\n',
#  'Mk911=Stimulus,S  2,603815,1,0\n',
#  'Mk912=Stimulus,S 11,603965,1,0\n',
#  'Mk913=Stimulus,S 17,604423,1,0\n',
#  'Mk914=Stimulus,S  2,605165,1,0\n',
#  'Mk915=Stimulus,S 11,605315,1,0\n',
#  'Mk916=Stimulus,S 12,605873,1,0\n',
#  'Mk917=Stimulus,S  3,606573,1,0\n',
#  'Mk918=Stimulus,S 11,606723,1,0\n',
#  'Mk919=Stimulus,S 18,607358,1,0\n',
#  'Mk920=Stimulus,S  3,608073,1,0\n',
#  'Mk921=Stimulus,S 11,608223,1,0\n',
#  'Mk922=Stimulus,S 12,608490,1,0\n',
#  'Mk923=Stimulus,S  2,609190,1,0\n',
#  'Mk924=Stimulus,S 11,609340,1,0\n',
#  'Mk925=Stimulus,S 15,610132,1,0\n',
#  'Mk926=Stimulus,S  4,610898,1,0\n',
#  'Mk927=Stimulus,S 11,611048,1,0\n',
#  'Mk928=Stimulus,S 19,611957,1,0\n',
#  'Mk929=Stimulus,S  9,612640,1,0\n',
#  'Mk930=Stimulus,S 11,612790,1,0\n',
#  'Mk931=Stimulus,S 19,613340,1,0\n',
#  'Mk932=Stimulus,S  5,613998,1,0\n',
#  'Mk933=Stimulus,S 11,614148,1,0\n',
#  'Mk934=Stimulus,S 19,614982,1,0\n',
#  'Mk935=Stimulus,S  2,615806,1,0\n',
#  'Mk936=Stimulus,S 11,615956,1,0\n',
#  'Mk937=Stimulus,S 18,616458,1,0\n',
#  'Mk938=Stimulus,S  3,617140,1,0\n',
#  'Mk939=Stimulus,S 11,617290,1,0\n',
#  'Mk940=Stimulus,S 16,617674,1,0\n',
#  'Mk941=Stimulus,S  4,618357,1,0\n',
#  'Mk942=Stimulus,S 11,618506,1,0\n',
#  'Mk943=Stimulus,S 14,619473,1,0\n',
#  'Mk944=Stimulus,S  5,620157,1,0\n',
#  'Mk945=Stimulus,S 11,620306,1,0\n',
#  'Mk946=Stimulus,S 14,621066,1,0\n',
#  'Mk947=Stimulus,S  1,621732,1,0\n',
#  'Mk948=Stimulus,S 11,621882,1,0\n',
#  'Mk949=Stimulus,S 19,622232,1,0\n',
#  'Mk950=Stimulus,S  4,622890,1,0\n',
#  'Mk951=Stimulus,S 11,623040,1,0\n',
#  'Mk952=Stimulus,S 19,623507,1,0\n',
#  'Mk953=Stimulus,S  4,624165,1,0\n',
#  'Mk954=Stimulus,S 11,624315,1,0\n',
#  'Mk955=Stimulus,S 12,624690,1,0\n',
#  'Mk956=Stimulus,S  1,625357,1,0\n',
#  'Mk957=Stimulus,S 11,625507,1,0\n',
#  'Mk958=Stimulus,S 19,625865,1,0\n',
#  'Mk959=Stimulus,S  8,626532,1,0\n',
#  'Mk960=Stimulus,S 11,626682,1,0\n',
#  'Mk961=Stimulus,S 17,627324,1,0\n',
#  'Mk962=Stimulus,S  6,628015,1,0\n',
#  'Mk963=Stimulus,S 11,628165,1,0\n',
#  'Mk964=Stimulus,S 17,628948,1,0\n',
#  'Mk965=Stimulus,S  9,629748,1,0\n',
#  'Mk966=Stimulus,S 11,629898,1,0\n',
#  'Mk967=Stimulus,S 19,630241,1,0\n',
#  'Mk968=Stimulus,S  2,630890,1,0\n',
#  'Mk969=Stimulus,S 11,631040,1,0\n',
#  'Mk970=Stimulus,S 17,631507,1,0\n',
#  'Mk971=Stimulus,S  6,632190,1,0\n',
#  'Mk972=Stimulus,S 11,632340,1,0\n',
#  'Mk973=Stimulus,S 19,632807,1,0\n',
#  'Mk974=Stimulus,S  9,633465,1,0\n',
#  'Mk975=Stimulus,S 11,633615,1,0\n',
#  'Mk976=Stimulus,S 19,634190,1,0\n',
#  'Mk977=Stimulus,S  6,673765,1,0\n',
#  'Mk978=Stimulus,S  3,674424,1,0\n',
#  'Mk979=Stimulus,S 11,674574,1,0\n',
#  'Mk980=Stimulus,S 17,675332,1,0\n',
#  'Mk981=Stimulus,S  7,676274,1,0\n',
#  'Mk982=Stimulus,S 11,676424,1,0\n',
#  'Mk983=Stimulus,S 17,676799,1,0\n',
#  'Mk984=Stimulus,S  4,677549,1,0\n',
#  'Mk985=Stimulus,S 11,677699,1,0\n',
#  'Mk986=Stimulus,S 17,677974,1,0\n',
#  'Mk987=Stimulus,S  5,678682,1,0\n',
#  'Mk988=Stimulus,S 11,678832,1,0\n',
#  'Mk989=Stimulus,S 15,679158,1,0\n',
#  'Mk990=Stimulus,S  6,679890,1,0\n',
#  'Mk991=Stimulus,S 11,680040,1,0\n',
#  'Mk992=Stimulus,S 15,680599,1,0\n',
#  'Mk993=Stimulus,S  3,681349,1,0\n',
#  'Mk994=Stimulus,S 11,681499,1,0\n',
#  'Mk995=Stimulus,S 17,682041,1,0\n',
#  'Mk996=Stimulus,S  8,682716,1,0\n',
#  'Mk997=Stimulus,S 11,682866,1,0\n',
#  'Mk998=Stimulus,S 19,683624,1,0\n',
#  'Mk999=Stimulus,S  4,684341,1,0\n',
#  'Mk1000=Stimulus,S 11,684491,1,0\n',
#  'Mk1001=Stimulus,S 19,684749,1,0\n',
#  'Mk1002=Stimulus,S  3,685390,1,0\n',
#  ...]
